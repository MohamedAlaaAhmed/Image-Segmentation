# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2025.8.3)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.2.1)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.2.4)
# Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 103.5 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1.2 cligj-0.7.2 rasterio-1.4.3

# %%
import os
import glob
import zipfile
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix ,jaccard_score
import seaborn as sns
import numpy as np
from skimage.transform import resize
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf
from skimage.transform import resize as sk_resize
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import random
import glob, rasterio
from tensorflow.keras.applications import ResNet50, EfficientNetB0, MobileNetV2
from skimage.transform import resize as sk_resize
from tensorflow.keras import layers, Model
from tensorflow.keras import layers, models

# %%
zip_path = "data.zip"
extract_path = "data_extracted"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
image_dir = os.path.join(extract_path, "data/images")
label_dir = os.path.join(extract_path, "data/labels")
print(os.listdir(extract_path))
print(os.listdir(image_dir))
print(os.listdir(label_dir))
# Out:
# ['data']
# ['87.tif', '199.tif', '162.tif', '193.tif', '75.tif', '172.tif', '13.tif', '268.tif', '47.tif', '155.tif', '102.tif', '191.tif', '251.tif', '67.tif', '17.tif', '242.tif', '256.tif', '209.tif', '22.tif', '60.tif', '293.tif', '296.tif', '19.tif', '281.tif', '214.tif', '77.tif', '34.tif', '4.tif', '236.tif', '271.tif', '235.tif', '156.tif', '40.tif', '275.tif', '64.tif', '273.tif', '128.tif', '129.tif', '224.tif', '63.tif', '98.tif', '194.tif', '173.tif', '24.tif', '105.tif', '228.tif', '35.tif', '134.tif', '78.tif', '154.tif', '133.tif', '269.tif', '279.tif', '225.tif', '143.tif', '91.tif', '42.tif', '117.tif', '302.tif', '289.tif', '74.tif', '116.tif', '11.tif', '226.tif', '189.tif', '220.tif', '104.tif', '125.tif', '110.tif', '223.tif', '68.tif', '175.tif', '27.tif', '270.tif', '153.tif', '249.tif', '16.tif', '26.tif', '112.tif', '161.tif', '121.tif', '69.tif', '206.tif', '208.tif', '3.tif', '101.tif', '86.tif', '48.tif', '217.tif', '280.tif', '100.tif', '177.tif', '211.tif', '184.tif', '96.tif', '157.tif', '212.tif', '39.tif', '159.tif', '12.tif', '147.tif', '56.tif', '218.tif', '71.tif', '18.tif', '138.tif', '123.tif', '255.tif', '165.tif', '106.tif', '29.tif', '244.tif', '51.tif', '264.tif', '83.tif', '210.tif', '139.tif', '192.tif', '84.tif', '259.tif', '164.tif', '248.tif', '274.tif', '57.tif', '53.tif', '37.tif', '201.tif', '237.tif', '85.tif', '166.tif', '45.tif', '1.tif', '261.tif', '31.tif', '130.tif', '185.tif', '277.tif', '7.tif', '146.tif', '202.tif', '58.tif', '30.tif', '89.tif', '196.tif', '10.tif', '243.tif', '213.tif', '234.tif', '103.tif', '298.tif', '265.tif', '240.tif', '287.tif', '120.tif', '119.tif', '285.tif', '216.tif', '232.tif', '
# | رقم القناة | الاسم                             | الطول الموجي (نانومتر) | الدقة (متر) | الاستخدام                                                  |
# | ---------- | --------------------------------- | ---------------------- | ----------- | ---------------------------------------------------------- |
# | **B1**     | Coastal aerosol (ساحلي/أزرق غامق) | 443                    | 60m         | قياس الجسيمات في الغلاف الجوي والبحر، تمييز السحب الرقيقة. |
# | **B2**     | Blue (أزرق)                       | 490                    | 10m         | تحليل المياه الضحلة، التمييز بين الماء/الأرض.              |
# | **B3**     | Green (أخضر)                      | 560                    | 10m         | يعكس الغطاء النباتي، قريب من ما تراه العين.                |
# | **B4**     | Red (أحمر)                        | 665                    | 10m         | يوضح التربة، يساعد في التمييز بين الماء/النباتات.          |
# | **B5**     | Vegetation Red Edge 1             | 705                    | 20m         | حساس لصحة النباتات (الانتقال من الأحمر إلى NIR).           |
# | **B6**     | Vegetation Red Edge 2             | 740                    | 20m         | تقييم الغطاء النباتي والكثافة.                             |
# | **B7**     | Vegetation Red Edge 3             | 783                    | 20m         | الغطاء النباتي (زي الـ B6 لكن بتردد مختلف).                |
# | **B8**     | NIR (Near Infrared)               | 842                    | 10m         | الماء = غامق جدًا / النبات = فاتح جدًا. أهم Band للزراعة.  |
# | **B8A**    | Narrow NIR                        | 865                    | 20m         | قياس دقيق لصحة النباتات، تكملة لـ NDVI.                    |
# | **B9**     | Water vapor                       | 945                    | 60m         | قياس بخار الماء في الغلاف الجوي.                           |
# | **B11**    | SWIR 1 (Shortwave Infrared)       | 1610                   | 20m         | التربة، الرطوبة، التمييز بين سحب/ثلج/جليد.                 |
# | **B12**    | SWIR 2 (Shortwave Infrared)       | 2190                   | 20m         | خرائط الحرائق، الجفاف، الصخور والمعادن.                    |
#
# ---
#
# ## 🎯 الاستخدام العملي
#
# * **الماء**: B2, B3, B4, B8 (لأنها تظهر المياه بوضوح).
# * **النباتات**: B5, B6, B7, B8, B8A (تظهر صحة الغطاء النباتي).
# * **التربة والصخور**: B11, B12 (للتفريق بين أنواع التربة والرطوبة).
# * **الغلاف الجوي**: B1, B9 (للتصحيح الجوي).

# %%
channel_names = [
    "Coastal aerosol",
    "Blue",
    "Green",
    "Red",
    "NIR",
    "SWIR1",
    "SWIR2",
    "QA Band",
    "Merit DEM",
    "Copernicus DEM",
    "ESA World Cover map",
    "Water occurrence probability"
]

img_files = os.listdir(image_dir)
img_path = os.path.join(image_dir, img_files[0])

with rasterio.open(img_path) as src:
    img = src.read()

print("Image shape:", img.shape)

num_channels = img.shape[0]
fig, axes = plt.subplots(3, 4, figsize=(15, 10))
axes = axes.flatten()

for i in range(num_channels):
    axes[i].imshow(img[i], cmap="gray")
    axes[i].set_title(channel_names[i], fontsize=9)
    axes[i].axis("off")

plt.tight_layout()
plt.show()
# Out:
# Image shape: (12, 128, 128)

# %% [markdown]
# 📌 معنى كل قناة:
#
# Band 2 (Blue)
#
# حساسة جدًا للمياه الضحلة.
#
# المياه بتمتص الضوء في الأزرق بشكل مميز مقارنة باليابسة.
#
# Band 3 (Green)
#
# بيساعد في التمييز بين المياه والنباتات.
#
# الماء غالبًا بيبان غامق، لكن الغطاء النباتي بيبان أفتح.
#
# Band 7 (NIR  Near Infrared)
#
# أهم قناة للكشف عن المياه.
#
# المياه بتمتص الـ NIR بقوة → بتظهر غامقة جدًا.
#
# اليابسة والنباتات بيعكسوا الـ NIR → بيظهروا فاتحين.

# %%
best_channels = ["Blue", "Green", "Red", "NIR", "SWIR1"]
selected_channels = [channel_names.index(band) for band in best_channels]

def load_dataset(image_dir, label_dir, selected_channels=selected_channels, target_size=(128,128)):

    images, masks = [], []

    image_files = sorted(glob.glob(os.path.join(image_dir, "*.tif")))
    label_files = sorted(glob.glob(os.path.join(label_dir, "*.png")))

    image_names = [os.path.splitext(os.path.basename(f))[0] for f in image_files]
    label_names = [os.path.splitext(os.path.basename(f))[0] for f in label_files]
    common_names = sorted(set(image_names).intersection(set(label_names)))

    print(f"Found {len(image_files)} images, {len(label_files)} masks, {len(common_names)} common pairs.")

    for name in common_names:
        img_path = os.path.join(image_dir, name + ".tif")
        lbl_path = os.path.join(label_dir, name + ".png")

        if not os.path.exists(img_path) or not os.path.exists(lbl_path):
            continue

        with rasterio.open(img_path) as src:
            img = src.read()
            img = np.transpose(img, (1,2,0))
            img = img[:,:,selected_channels]

        img_resized = sk_resize(img, target_size, preserve_range=True)
        img_resized = (img_resized - img_resized.min()) / (img_resized.max() - img_resized.min() + 1e-6)

        mask = rasterio.open(lbl_path).read(1)
        mask = (mask > 0).astype(np.float32)

        mask_resized = sk_resize(mask, target_size, preserve_range=True, anti_aliasing=True)
        mask_resized = (mask_resized > 0.5).astype(np.float32)

        images.append(img_resized)
        masks.append(mask_resized)

    X = np.array(images, dtype=np.float32)
    Y = np.array(masks, dtype=np.float32)
    Y = np.expand_dims(Y, axis=-1)

    print("Dataset shape:", X.shape, Y.shape)
    return X, Y


X, Y = load_dataset(image_dir, label_dir)
# Out:
# Found 306 images, 455 masks, 306 common pairs.
# Dataset shape: (306, 128, 128, 5) (306, 128, 128, 1)

# %%
def preview_dataset(images, masks, n=5):
    plt.figure(figsize=(15, 6))
    for i in range(n):
        img = images[i][:,:, [3,1,0]]

        plt.subplot(2, n, i+1)
        plt.imshow(img)
        plt.title(f"Image {i}")
        plt.axis("off")

        plt.subplot(2, n, i+1+n)
        plt.imshow(masks[i].squeeze(), cmap="gray")
        plt.title(f"Mask {i}")
        plt.axis("off")
    plt.show()


preview_dataset(X, Y, n=5)

# %%
def preview_dataset2(images, masks, n=5):
    plt.figure(figsize=(15, 6))
    for i in range(n):
        img = images[i][:,:, [3,4,0]]

        plt.subplot(2, n, i+1)
        plt.imshow(img)
        plt.title(f"Image {i}")
        plt.axis("off")

        plt.subplot(2, n, i+1+n)
        plt.imshow(masks[i].squeeze(), cmap="gray")
        plt.title(f"Mask {i}")
        plt.axis("off")
    plt.show()

#
preview_dataset2(X, Y, n=5)

# %%
def preview_dataset3(images, masks, n=5):
    plt.figure(figsize=(15, 6))
    for i in range(n):
        img = images[i][:,:, [2,4,0]]

        plt.subplot(2, n, i+1)
        plt.imshow(img)
        plt.title(f"Image {i}")
        plt.axis("off")

        plt.subplot(2, n, i+1+n)
        plt.imshow(masks[i].squeeze(), cmap="gray")
        plt.title(f"Mask {i}")
        plt.axis("off")
    plt.show()


preview_dataset3(X, Y, n=5)

# %%
def preview_dataset4(images, masks, n=3, band_names=["Blue","Green","Red","NIR","SWIR1"]):
    for i in range(n):
        plt.figure(figsize=(15, 8))

        for j in range(images.shape[-1]):
            plt.subplot(2, images.shape[-1]//2 + 2, j+1)
            plt.imshow(images[i][:,:,j], cmap="gray")
            plt.title(f"{band_names[j]}")
            plt.axis("off")

        rgb_img = images[i][:,:, [2,1,0]]
        plt.subplot(2, images.shape[-1]//2 + 2, images.shape[-1]+1)
        plt.imshow(rgb_img)
        plt.title("RGB Composite")
        plt.axis("off")

        plt.subplot(2, images.shape[-1]//2 + 2, images.shape[-1]+2)
        plt.imshow(masks[i].squeeze(), cmap="gray")
        plt.title("Mask")
        plt.axis("off")

        plt.suptitle(f"Sample {i}", fontsize=14)
        plt.tight_layout()
        plt.show()

# %%
preview_dataset4(X, Y, n=3)

# %%
images = X.astype(np.float32) / 255.0
masks = Y.astype(np.float32)
masks = np.expand_dims(masks, axis=-1)

print("Images shape:", images.shape)
print("Masks shape:", masks.shape)
# Out:
# Images shape: (306, 128, 128, 5)
# Masks shape: (306, 128, 128, 1, 1)

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(
    images, masks, test_size=0.2, random_state=42
)

# %%
def unet_model(input_shape):
    inputs = layers.Input(input_shape)

    X = layers.Conv2D(16, 3, activation="relu", padding="same")(inputs)
    X = layers.Conv2D(16, 3, activation="relu", padding="same")(X)
    X = layers.MaxPooling2D()(X)

    X = layers.Conv2D(32,3, activation="relu", padding="same")(X)
    X = layers.Conv2D(32,3, activation="relu", padding="same")(X)
    X = layers.MaxPooling2D()(X)

    X = layers.Conv2D(64,3, activation="relu", padding="same")(X)
    X = layers.Conv2D(64,3, activation="relu", padding="same")(X)

    X = layers.UpSampling2D()(X)
    X = layers.Concatenate()([X, X])
    X = layers.Conv2D(32, 3, activation="relu", padding="same")(X)
    X = layers.Conv2D(32, 3, activation="relu", padding="same")(X)

    X = layers.UpSampling2D()(X)
    X = layers.Concatenate()([X, X])
    X = layers.Conv2D(16, 3, activation="relu", padding="same")(X)
    X = layers.Conv2D(16,3, activation="relu", padding="same")(X)

    outputs = layers.Conv2D(1,1, activation="sigmoid")(X)

    model = models.Model(inputs, outputs)
    return model

model1 = unet_model(input_shape=X_train1.shape[1:])

model1.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 5)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 128, 128,  │        736 │ input_layer_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 128, 128,  │      2,320 │ conv2d_22[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 64, 64,    │          0 │ conv2d_23[0][0]   │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 64, 64,    │      4,640 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 64, 64,    │      9,248 │ conv2d_24[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 32, 32,    │          0 │ conv2d_25[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 32, 32,    │     18,496 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 32, 32,    │     36,928 │ conv2d_26[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 64, 64,    │          0 │ conv2d_27[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 64, 64,    │          0 │ up_sampling2d_4[… │
# │ (Concatenate)       │ 128)              │            │ up_sampling2d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 64, 64,    │     36,896 │ concatenate_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 64, 64,    │      9,248 │ conv2d_28[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 128, 128,  │          0 │ conv2d_29[0][0]   │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 128, 128,  │          0 │ up_sampling2d_5[… │
# │ (Concatenate)       │ 64)               │            │ up_sampling2d_5[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │      9,232 │ concatenate_5[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 128, 128,  │      2,320 │ conv2d_30[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │         17 │ conv2d_31[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 130,081 (508.13 KB)
#  Trainable params: 130,081 (508.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model1.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
checkpoint_path = "best_model.keras"

checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

# %%
history = model1.fit(
    X_train1, y_train1,
    validation_data=(X_test1, y_test1),
    epochs=100,
    batch_size=8,
    callbacks= checkpoint
)
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7047 - loss: 0.6530
# Epoch 1: val_accuracy improved from -inf to 0.77563, saving model to best_model.keras
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7055 - loss: 0.6521 - val_accuracy: 0.7756 - val_loss: 0.5351
# Epoch 2/100
# 28/31 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7240 - loss: 0.5983
# Epoch 2: val_accuracy did not improve from 0.77563
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7247 - loss: 0.5973 - val_accuracy: 0.7756 - val_loss: 0.5363
# Epoch 3/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7589 - loss: 0.5574
# Epoch 3: val_accuracy did not improve from 0.77563
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7561 - loss: 0.5598 - val_accuracy: 0.7756 - val_loss: 0.5113
# Epoch 4/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7524 - loss: 0.4910
# Epoch 4: val_accuracy did not improve from 0.77563
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7502 - loss: 0.4915 - val_accuracy: 0.7756 - val_loss: 0.4278
# Epoch 5/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7452 - loss: 0.4754
# Epoch 5: val_accuracy improved from 0.77563 to 0.87171, saving model to best_model.keras
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7505 - loss: 0.4726 - val_accuracy: 0.8717 - val_loss: 0.3565
# Epoch 6/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8557 - loss: 0.3999
# Epoch 6: val_accuracy did not improve from 0.87171
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8558 - loss: 0.4001 - val_accuracy: 0.7756 - val_loss: 0.4562
# Epoch 7/100
# 30/31 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7204 - loss: 0.5446
# Epoch 7: val_accuracy improved from 0.87171 to 0.88143, saving model to best_model.keras
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7225 - loss: 0.5419 - val_accuracy: 0.8814 - val_loss: 0.3866
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8476 - loss: 0.4648
# Epoch 8: val_accuracy improved from 0.88143 to 0.89559, saving model to best_model.keras
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8483 - loss: 0.4622 - val_accuracy: 0.8956 - val_loss: 0.3073
# Epoch 9/100
# 28/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8250 - loss: 0.4808
# Epoch 9: val_accuracy did not improve from 0.89559
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8258 - loss: 0.4793 - val_accuracy: 0.8900 - val_loss: 0.3356
# Epoch 10/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8726 - loss: 0.3679
# Epoch 10: val_accuracy did not improve from 0.89559
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8729 - loss: 0.3665 - val_accuracy: 0.8917 - val_loss: 0.3165
# Epoch 11/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8831 - loss: 0.3337
# Epoch 11: val_accuracy improved from 0.89559 to 0.89725, saving model to best_model.keras
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8825 - loss: 0.3344 - val_accuracy: 0.8973 - val_loss: 0.3045
# Epoch 12/100
# 28/31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8848 - loss: 0.3384
# Epoch 12: val_accuracy did not improve from 0.89725
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8848 - loss: 0.3376 - val_accuracy: 0.8758 - val_loss: 0.3581
# Epoch 13/100
# 29/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.
31 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8974 - loss: 0.2744
# Epoch 99: val_accuracy did not improve from 0.91764
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8983 - loss: 0.2731 - val_accuracy: 0.9168 - val_loss: 0.2383
# Epoch 100/100
# 28/31 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9164 - loss: 0.2434
# Epoch 100: val_accuracy did not improve from 0.91764
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9155 - loss: 0.2454 - val_accuracy: 0.9033 - val_loss: 0.2654

# %%
loss, acc = model1.evaluate(X_test1, y_test1)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {acc:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.9063 - loss: 0.2598
# Test Loss: 0.2654, Test Accuracy: 0.9033

# %%
y_pred = model1.predict(X_test1)
y_pred_binary = (y_pred > 0.5).astype(int).flatten()
y_true_binary = y_test1.astype(int).flatten()

print("\nClassification Report:")
print(classification_report(y_true_binary, y_pred_binary))

cm = confusion_matrix(y_true_binary, y_pred_binary)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["BG","Fire"], yticklabels=["BG","Fire"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

tn, fp, fn, tp = cm.ravel()
iou = tp / (tp + fp + fn)
print(f"IoU: {iou:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94    787894
#            1       0.82      0.73      0.77    227914
#
#     accuracy                           0.90   1015808
#    macro avg       0.87      0.84      0.85   1015808
# weighted avg       0.90      0.90      0.90   1015808
# IoU: 0.6277

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

def test_prediction(model, X_test1, y_test1, n=3):

    for i in range(n):
        idx = random.randint(0, len(X_test1)-1)
        image = X_test1[idx]
        mask_true = y_test1[idx]

        # توقع الماسك واضغط الأبعاد
        mask_pred = model.predict(image[np.newaxis, ...])
        mask_pred = (mask_pred > 0.5).astype(int)
        mask_pred = np.squeeze(mask_pred)   # يخليها (128,128)

        plt.figure(figsize=(12,4))

        plt.subplot(1,3,1)
        plt.imshow(image[:,:,0], cmap="gray")
        plt.title("Original Image")
        plt.axis("off")

        plt.subplot(1,3,2)
        plt.imshow(np.squeeze(mask_true), cmap="gray")
        plt.title("Ground Truth Mask")
        plt.axis("off")

        plt.subplot(1,3,3)
        plt.imshow(mask_pred, cmap="gray")
        plt.title("Predicted Mask")
        plt.axis("off")

        plt.show()

# %%
test_prediction(model1, X_test1, y_test1, n=5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
zip_path = "data.zip"
extract_path = "data_extracted2"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
image_dir2 = os.path.join(extract_path, "data/images")
label_dir2 = os.path.join(extract_path, "data/labels")
print(os.listdir(extract_path))
print(os.listdir(image_dir2))
print(os.listdir(label_dir2))
# Out:
# ['data']
# ['87.tif', '199.tif', '162.tif', '193.tif', '75.tif', '172.tif', '13.tif', '268.tif', '47.tif', '155.tif', '102.tif', '191.tif', '251.tif', '67.tif', '17.tif', '242.tif', '256.tif', '209.tif', '22.tif', '60.tif', '293.tif', '296.tif', '19.tif', '281.tif', '214.tif', '77.tif', '34.tif', '4.tif', '236.tif', '271.tif', '235.tif', '156.tif', '40.tif', '275.tif', '64.tif', '273.tif', '128.tif', '129.tif', '224.tif', '63.tif', '98.tif', '194.tif', '173.tif', '24.tif', '105.tif', '228.tif', '35.tif', '134.tif', '78.tif', '154.tif', '133.tif', '269.tif', '279.tif', '225.t
png', '118_125.png', '250.png', '72_205.png', '95_221.png', '65.png', '176.png', '127.png', '141_237.png', '25_172.png', '57.png', '95.png', '67.png', '96.png', '120.png', '46_55.png', '17_60.png', '74.png', '53_43.png', '86.png', '266.png', '138.png', '119.png', '252.png', '113.png', '16_229.png', '231.png', '107.png', '228.png', '298.png', '129.png', '87.png', '206.png', '122_257.png', '83_131.png', '216.png', '244.png', '125_201.png', '62_187.png', '45.png', '103.png', '275.png', '249.png', '63.png', '193.png', '251.png', '81_9.png', '159.png', '149.png', '140_34.png', '110.png', '18.png', '192.png', '69.png', '67_156.png', '122.png', '137_140.png', '9_202.png', '149_166.png', '147_213.png', '24.png', '185.png', '54_51.png', '38.png', '243.png', '28_2.png', '21_25 ...

# %%
label_dir2 = os.path.join(extract_path, "data/labels")

for filename in os.listdir(label_dir2):
    new_name = filename.replace("_", "")
    old_path = os.path.join(label_dir2, filename)
    new_path = os.path.join(label_dir2, new_name)
    os.rename(old_path, new_path)

print("Renamed masks:", os.listdir(label_dir2)[:10])
# Out:
# Renamed masks: ['163.png', '26.png', '5343.png', '13556.png', '8.png', '218.png', '36240.png', '19.png', '141.png', '71.png']

# %%
channel_names = [
    "Coastal aerosol",
    "Blue",
    "Green",
    "Red",
    "NIR",
    "SWIR1",
    "SWIR2",
    "QA Band",
    "Merit DEM",
    "Copernicus DEM",
    "ESA World Cover map",
    "Water occurrence probability"
]

def load_dataset(image_dir2, label_dir2, target_size=(128,128)):
    images, masks = [], []

    image_files = sorted(glob.glob(os.path.join(image_dir2, "*.tif")))
    label_files = sorted(glob.glob(os.path.join(label_dir2, "*.png")))

    image_names = [os.path.splitext(os.path.basename(f))[0] for f in image_files]
    label_names = [os.path.splitext(os.path.basename(f))[0] for f in label_files]
    common_names = sorted(set(image_names).intersection(set(label_names)))

    print(f"Found {len(image_files)} images, {len(label_files)} masks, {len(common_names)} common pairs.")

    for name in common_names:
        img_path = os.path.join(image_dir2, name + ".tif")
        lbl_path = os.path.join(label_dir2, name + ".png")

        if not os.path.exists(img_path) or not os.path.exists(lbl_path):
            continue

        with rasterio.open(img_path) as src:
            img = src.read()
            img = np.transpose(img, (1,2,0))

        img_resized = sk_resize(img, target_size, preserve_range=True)
        img_resized = (img_resized - img_resized.min()) / (img_resized.max() - img_resized.min() + 1e-6)

        mask = rasterio.open(lbl_path).read(1)
        mask_resized = sk_resize(mask, target_size, preserve_range=True, anti_aliasing=True)
        mask_resized = (mask_resized > 0.5).astype(np.float32)

        images.append(img_resized)
        masks.append(mask_resized)

    X = np.array(images, dtype=np.float32)
    Y = np.array(masks, dtype=np.float32)
    Y = np.expand_dims(Y, axis=-1)

    print("Dataset shape:", X.shape, Y.shape)
    return X, Y

X, Y = load_dataset(image_dir2, label_dir2)
# Out:
# Found 306 images, 455 masks, 306 common pairs.
# /usr/local/lib/python3.12/dist-packages/rasterio/__init__.py:356: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# Dataset shape: (306, 128, 128, 12) (306, 128, 128, 1)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def ChannelSelector(input_shape, top_k=3):
    inputs = layers.Input(shape=input_shape)

    weights = layers.Conv2D(1, (1,1), use_bias=False, name="channel_weights")(inputs)

    channel_scores = layers.Lambda(lambda x: tf.reduce_mean(x, axis=[0,1]), name="channel_scores")(weights)

    model = models.Model(inputs, [weights, channel_scores], name="ChannelSelector")
    return model

model = ChannelSelector((128,128,X.shape[-1]), top_k=3)

model.compile(
    optimizer="adam",
    loss={
        "channel_weights": "binary_crossentropy",   
        "channel_scores": None                      
    },
    metrics={"channel_weights": "accuracy"}
)

history = model.fit(
    X,
    {"channel_weights": Y, "channel_scores": tf.zeros((len(X), X.shape[-1]))},
    epochs=5, batch_size=8, validation_split=0.2
)

channel_layer = model.get_layer("channel_weights")
weights = channel_layer.get_weights()[0]   
weights = weights.squeeze()                

top_values, top_indices = tf.math.top_k(weights, k=3)
print("Top 3 Channels:")
for idx, val in zip(top_indices.numpy(), top_values.numpy()):
    print(f"{channel_names[idx]} -> Score: {val:.4f}")
# Out:
# Epoch 1/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - channel_weights_accuracy: 0.7257 - loss: 1.8617 - val_channel_weights_accuracy: 0.7796 - val_loss: 1.6480
# Epoch 2/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - channel_weights_accuracy: 0.7380 - loss: 1.5948 - val_channel_weights_accuracy: 0.7796 - val_loss: 1.4326
# Epoch 3/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - channel_weights_accuracy: 0.7629 - loss: 1.3819 - val_channel_weights_accuracy: 0.7796 - val_loss: 1.1276
# Epoch 4/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - channel_weights_accuracy: 0.7523 - loss: 1.2936 - val_channel_weights_accuracy: 0.7796 - val_loss: 0.8523
# Epoch 5/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - channel_weights_accuracy: 0.7423 - loss: 0.9324 - val_channel_weights_accuracy: 0.7797 - val_loss: 0.6257
# Top 3 Channels:
# Red -> Score: 0.5739
# Green -> Score: 0.4796
# Merit DEM -> Score: 0.4469

# %%
def preview_channels_separately(images, masks, selected_channels, n=3):
    import numpy as np

    # لو selected_channels أسماء → حولها ل indices
    if isinstance(selected_channels[0], str):
        selected_channels = [channel_names.index(ch) for ch in selected_channels]

    num_channels = len(selected_channels)
    plt.figure(figsize=(5 * num_channels, 4 * n))

    for i in range(n):
        for j, ch in enumerate(selected_channels):
            img = images[i][:,:,ch]
            img_disp = (img - img.min()) / (img.max() - img.min() + 1e-6)

            plt.subplot(n, num_channels*2, i*num_channels*2 + j*2 + 1)
            plt.imshow(img_disp, cmap="gray")
            plt.title(f"Image {i} - {channel_names[ch]}")
            plt.axis("off")

            plt.subplot(n, num_channels*2, i*num_channels*2 + j*2 + 2)
            plt.imshow(masks[i].squeeze(), cmap="gray")
            plt.title("Mask")
            plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
best_channels = ["Red", "Green", "Merit DEM"]

best_channels_idx = [channel_names.index(ch) for ch in best_channels]

preview_channels_separately(X, Y, best_channels_idx, n=3)

# %%
X_selected = X[:,:,:,best_channels_idx]

print("Original X shape:", X.shape)
print("Selected X shape:", X_selected.shape)
# Out:
# Original X shape: (306, 128, 128, 12)
# Selected X shape: (306, 128, 128, 3)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    X_selected, Y, test_size=0.2, random_state=42
)

print("Train shape:", X_train.shape, Y_train.shape)
print("Test shape:", X_test.shape, Y_test.shape)
# Out:
# Train shape: (244, 128, 128, 3) (244, 128, 128, 1)
# Test shape: (62, 128, 128, 3) (62, 128, 128, 1)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def build_resnet34(input_shape=(128,128,3), num_classes=1):
    # Load Pretrained ResNet34 من keras.applications (هنا هنستخدم ResNet50 كبديل لأن ResNet34 مش موجود رسمي في keras)
    base_model = tf.keras.applications.ResNet50(
        weights="imagenet", include_top=False, input_shape=input_shape
    )

    # نحدد ال layers اللي هنستخدمها في الـ skip connections
    skips = [
        base_model.get_layer("conv1_relu").output,   # 64 filters
        base_model.get_layer("conv2_block3_out").output,  # 256 filters
        base_model.get_layer("conv3_block4_out").output,  # 512 filters
        base_model.get_layer("conv4_block6_out").output,  # 1024 filters
    ]
    encoder_output = base_model.get_layer("conv5_block3_out").output  # 2048 filters

    # Decoder (Upsampling + Skip connections)
    x = encoder_output
    for skip in reversed(skips):
        x = layers.Conv2DTranspose(256, (3,3), strides=(2,2), padding="same")(x)
        x = layers.concatenate([x, skip])
        x = layers.Conv2D(256, (3,3), activation="relu", padding="same")(x)
        x = layers.Conv2D(256, (3,3), activation="relu", padding="same")(x)

    # Final upsampling
    x = layers.Conv2DTranspose(128, (3,3), strides=(2,2), padding="same")(x)
    x = layers.Conv2D(64, (3,3), activation="relu", padding="same")(x)

    outputs = layers.Conv2D(num_classes, (1,1), activation="sigmoid")(x)

    model = models.Model(inputs=base_model.input, outputs=outputs, name="U-Net_ResNet50")
    return model

# %%
model = build_resnet34(input_shape=(128,128,3), num_classes=1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
checkpoint_path = "resnet34_model.keras"

checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.MeanIoU(num_classes=2)]
)

model.summary()
# Out:
# Model: "U-Net_ResNet50"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 134, 134,  │          0 │ input_layer_7[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 64, 64,    │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 64, 64,    │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 64, 64,    │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 66, 66,    │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 32, 32,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 32, 32,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 32, 32,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 32, 32,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 32, 32,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 32, 32,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 32, 32,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 32, 32,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 32, 32,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 32, 32,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 32, 32,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 32, 32,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 32, 32,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 32, 32,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 32, 32,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 32, 32,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 32, 32,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 32, 32,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 32, 32,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 32, 32,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 32, 32,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 32, 32,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 32, 32,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 32, 32,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 32, 32,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 32, 32,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 32, 32,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 32, 32,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 32, 32,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 32, 32,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 32, 32,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 32, 32,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 32, 32,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 16, 16,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 16, 16,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 16, 16,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 16, 16,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 16, 16,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 16, 16,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 16, 16,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 16, 16,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 16, 16,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 16, 16,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 16, 16,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 16, 16,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 16, 16,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 16, 16,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 16, 16,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 16, 16,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 16, 16,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 16, 16,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 16, 16,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 16, 16,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 16, 16,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 16, 16,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 16, 16,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 16, 16,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 16, 16,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 16, 16,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 16, 16,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 16, 16,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 16, 16,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 16, 16,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 16, 16,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 16, 16,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 16, 16,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 16, 16,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 16, 16,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 16, 16,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 16, 16,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 16, 16,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 8, 8, 256) │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 8, 8,      │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 8, 8,      │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 8, 8,      │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 8, 8,      │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 8, 8,      │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 8, 8,      │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 8, 8,      │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 8, 8,      │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block4_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block4_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 8, 8,      │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 8, 8,      │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block5_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block5_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 8, 8,      │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 8, 8,      │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block6_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block6_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 8, 8,      │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 8, 8,      │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 4, 4, 512) │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 4, 4, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 4, 4, 512) │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 4, 4, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 4, 4,      │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 4, 4,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 4, 4,      │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 4, 4,      │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 4, 4,      │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 4, 4,      │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 4, 4, 512) │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 4, 4, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 4, 4, 512) │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 4, 4, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 4, 4,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 4, 4,      │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 4, 4,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 4, 4,      │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 4, 4, 512) │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 4, 4, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 4, 4, 512) │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 4, 4, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 4, 4,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 4, 4,      │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 4, 4,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 4, 4,      │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 256) │  4,718,848 │ conv5_block3_out… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 8, 8,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1280)             │            │ conv4_block6_out… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 8, 8, 256) │  2,949,376 │ concatenate_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ conv2d_33[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │    590,080 │ conv2d_34[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 768)              │            │ conv3_block4_out… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 16, 16,    │  1,769,728 │ concatenate_7[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 16, 16,    │    590,080 │ conv2d_35[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │    590,080 │ conv2d_36[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2_block3_out… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate_8[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 32, 32,    │    590,080 │ conv2d_37[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │    590,080 │ conv2d_38[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 320)              │            │ conv1_relu[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 64, 64,    │    737,536 │ concatenate_9[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_39[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │    295,040 │ conv2d_40[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 128, 128,  │     73,792 │ conv2d_transpose… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 128, 128,  │         65 │ conv2d_41[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 39,442,561 (150.46 MB)
#  Trainable params: 39,389,441 (150.26 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
history = model.fit(
    X_train, Y_train,
    validation_data=(X_test, Y_test),
    epochs=100,
    batch_size=8,
    callbacks=checkpoint
)
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6818 - loss: 0.9586 - mean_io_u_1: 0.3729
# Epoch 1: val_accuracy improved from -inf to 0.32477, saving model to resnet34_model.keras
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - accuracy: 0.6827 - loss: 0.9511 - mean_io_u_1: 0.3726 - val_accuracy: 0.3248 - val_loss: 10.4828 - val_mean_io_u_1: 0.3832
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.6715 - loss: 0.6564 - mean_io_u_1: 0.3710
# Epoch 2: val_accuracy did not improve from 0.32477
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 192ms/step - accuracy: 0.6731 - loss: 0.6545 - mean_io_u_1: 0.3708 - val_accuracy: 0.2339 - val_loss: 327.8961 - val_mean_io_u_1: 0.1311
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7332 - loss: 0.5966 - mean_io_u_1: 0.3567
# Epoch 3: val_accuracy improved from 0.32477 to 0.61570, saving model to resnet34_model.keras
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 396ms/step - accuracy: 0.7332 - loss: 0.5964 - mean_io_u_1: 0.3570 - val_accuracy: 0.6157 - val_loss: 1022.3398 - val_mean_io_u_1: 0.3952
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7873 - loss: 0.5080 - mean_io_u_1: 0.3677
# Epoch 4: val_accuracy did not improve from 0.61570
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 181ms/step - accuracy: 0.7876 - loss: 0.5077 - mean_io_u_1: 0.3676 - val_accuracy: 0.4286 - val_loss: 3.3305 - val_mean_io_u_1: 0.3967
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8083 - loss: 0.4677 - mean_io_u_1: 0.3581
# Epoch 5: val_accuracy did not improve from 0.61570
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.8081 - loss: 0.4680 - mean_io_u_1: 0.3583 - val_accuracy: 0.2244 - val_loss: 3.4626 - val_mean_io_u_1: 0.3878
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8215 - loss: 0.4578 - mean_io_u_1: 0.3628
# Epoch 6: val_accuracy did not improve from 0.61570
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.8216 - loss: 0.4571 - mean_io_u_1: 0.3628 - val_accuracy: 0.2695 - val_loss: 4.4940 - val_mean_io_u_1: 0.3897
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8238 - loss: 0.4175 - mean_io_u_1: 0.3641
# Epoch 7: val_accuracy did not improve from 0.61570
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.8232 - loss: 0.4189 - mean_io_u_1: 0.3642 - val_accuracy: 0.2250 - val_loss: 0.7895 - val_mean_io_u_1: 0.3878
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8008 - loss: 0.4635 - mean_io_u_1: 0.3776
# Epoch 8: val_accuracy did not improve from 0.61570
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.8003 - loss: 0.4644 - mean_io_u_1: 0.3775 - val_accuracy: 0.5192 - val_loss: 0.6864 - val_mean_io_u_1: 0.3878
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8031 - loss: 0.4611 - mean_io_u_1: 0.3705
# Epoch 9: val_accuracy did not improve from 0.61570
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 183ms/step - accuracy: 0.9006 - loss: 0.2517 - mean_io_u_1: 0.3611 - val_accuracy: 0.7672 - val_loss: 0.6372 - val_mean_io_u_1: 0.4122
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8957 - loss: 0.2528 - mean_io_u_1: 0.3713
# Epoch 52: val_accuracy improved from 0.88040 to 0.89670, saving model to resnet34_model.keras
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.8955 - loss: 0.2532 - mean_io_u_1: 0.3711 - val_accuracy: 0.8967 - val_loss: 0.2582 - val_mean_io_u_1: 0.3878
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8975 - loss: 0.2514 - mean_io_u_1: 0.3599
# Epoch 53: val_accuracy did not improve from 0.89670
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.8972 - loss: 0.2518 - mean_io_u_1: 0.3601 - val_accuracy: 0.8262 - val_loss: 0.3775 - val_mean_io_u_1: 0.3915
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8889 - loss: 0.2705 - mean_io_u_1: 0.3675
# Epoch 54: val_accuracy did not improve from 0.89670
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 183ms/step - accuracy: 0.8890 - loss: 0.2704 - mean_io_u_1: 0.3676 - val_accuracy: 0.8960 - val_loss: 0.2555 - val_mean_io_u_1: 0.4260
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8937 - loss: 0.2522 - mean_io_u_1: 0.3698
# Epoch 55: val_accuracy did not improve from 0.89670
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.8938 - loss: 0.2523 - mean_io_u_1: 0.3697 - val_accuracy: 0.8778 - val_loss: 0.3333 - val_mean_io_u_1: 0.4076
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8851 - loss: 0.2883 - mean_io_u_1: 0.3675
# Epoch 56: val_accuracy did not improve from 0.89670
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.8851 - loss: 0.2886 - mean_io_u_1: 0.3674 - val_accuracy: 0.8834 - val_loss: 0.2813 - val_mean_io_u_1: 0.4118
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8940 - loss: 0.2659 - mean_io_u_1: 0.3666
# Epoch 57: val_accuracy did not improve from 0.89670
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 187ms/step - accuracy: 0.8939 - loss: 0.2661 - mean_io_u_1: 0.3665 - val_accuracy: 0.8048 - val_loss: 0.5086 - val_mean_io_u_1: 0.3910
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8980 - loss: 0.2620 - mean_io_u_1: 0.3660
# Epoch 58: val_accuracy did not improve from 0.89670
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 185ms/step - accuracy: 0.8979 - loss: 0.2623 - mean_io_u_1: 0.3660 - val_accuracy: 0.8367 - val_loss: 0.4280 - val_mean_io_u_1: 0.3878
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9013 - loss: 0.2486 - mean_io_u_1: 0.3639
# Epoch 59: val_accuracy did not improve from 0.89670
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 186ms/step - accuracy: 0.9010 - loss: 0.2491 - mean_io_u_1: 0.3639 - val_accuracy: 0.8414 - val_loss: 0.3388 - val_mean_io_u_1: 0.4091
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8974 - loss: 0.2452 - mean_io_u_1: 0.3728
# Epoch 60: val_accuracy did not improve from 0.89670
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.8972 - loss: 0.2456 - mean_io_u_1: 0.3731 - val_accuracy: 0.8393 - val_loss: 0.3799 - val_mean_io_u_1: 0.3946
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9025 - loss: 0.2408 - mean_io_u_1: 0.3847
# Epoch 61: val_accuracy did not improve from 0.89670
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.9023 - loss: 0.2413 - mean_io_u_1: 0.3844 - val_accuracy: 0.8063 - val_loss: 0.4321 - val_mean_io_u_1: 0.4260
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.
100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9285 - loss: 0.1753 - mean_io_u_1: 0.3505
# Epoch 96: val_accuracy did not improve from 0.90387
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 186ms/step - accuracy: 0.9286 - loss: 0.1750 - mean_io_u_1: 0.3509 - val_accuracy: 0.8922 - val_loss: 0.3986 - val_mean_io_u_1: 0.3878
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9279 - loss: 0.1767 - mean_io_u_1: 0.3610
# Epoch 97: val_accuracy did not improve from 0.90387
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.9280 - loss: 0.1767 - mean_io_u_1: 0.3611 - val_accuracy: 0.8873 - val_loss: 0.2944 - val_mean_io_u_1: 0.3878
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9402 - loss: 0.1546 - mean_io_u_1: 0.3655
# Epoch 98: val_accuracy did not improve from 0.90387
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 186ms/step - accuracy: 0.9400 - loss: 0.1550 - mean_io_u_1: 0.3655 - val_accuracy: 0.8845 - val_loss: 0.2788 - val_mean_io_u_1: 0.3878
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9261 - loss: 0.1832 - mean_io_u_1: 0.3499
# Epoch 99: val_accuracy improved from 0.90387 to 0.90893, saving model to resnet34_model.keras
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 29s 966ms/step - accuracy: 0.9264 - loss: 0.1824 - mean_io_u_1: 0.3503 - val_accuracy: 0.9089 - val_loss: 0.2739 - val_mean_io_u_1: 0.3878
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9397 - loss: 0.1510 - mean_io_u_1: 0.3598
# Epoch 100: val_accuracy improved from 0.90893 to 0.91378, saving model to resnet34_model.keras
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 25s 819ms/step - accuracy: 0.9395 - loss: 0.1515 - mean_io_u_1: 0.3600 - val_accuracy: 0.9138 - val_loss: 0.2345 - val_mean_io_u_1: 0.3878

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import tensorflow as tf

# 1) Evaluate model على test set
test_loss, test_acc, test_iou = model.evaluate(X_test, Y_test)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test Mean IoU: {test_iou:.4f}")

# 2) Get predictions
y_pred = model.predict(X_test)
y_pred_bin = (y_pred > 0.5).astype(int)

# Flatten for metrics
y_true_flat = Y_test.flatten()
y_pred_flat = y_pred_bin.flatten()

# 3) Classification report
print("\nClassification Report:")
print(classification_report(y_true_flat, y_pred_flat))

# 4) Confusion Matrix
cm = confusion_matrix(y_true_flat, y_pred_flat)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["BG","FG"], yticklabels=["BG","FG"])
plt.title("Confusion Matrix")
plt.show()

# 5) IoU function
def compute_iou(y_true, y_pred):
    intersection = np.logical_and(y_true, y_pred).sum()
    union = np.logical_or(y_true, y_pred).sum()
    if union == 0:
        return 1.0
    return intersection / union

# IoU لكل صورة
ious = []
for i in range(len(X_test)):
    iou = compute_iou(Y_test[i].squeeze(), y_pred_bin[i].squeeze())
    ious.append(iou)

print(f"Average IoU over test set: {np.mean(ious):.4f}")

# 6) Visualization
def visualize_predictions(X, Y, preds, n=3):
    plt.figure(figsize=(12, n*4))
    for i in range(n):
        iou = compute_iou(Y[i].squeeze(), preds[i].squeeze())

        # الصورة الأصلية
        plt.subplot(n,3,3*i+1)
        plt.imshow(X[i])
        plt.title("Input Image")
        plt.axis("off")

        # الماسك الحقيقي
        plt.subplot(n,3,3*i+2)
        plt.imshow(Y[i].squeeze(), cmap="gray")
        plt.title("Ground Truth")
        plt.axis("off")

        # الماسك المتوقع
        plt.subplot(n,3,3*i+3)
        plt.imshow(preds[i].squeeze(), cmap="gray")
        plt.title(f"Predicted (IoU={iou:.2f})")
        plt.axis("off")
    plt.show()

visualize_predictions(X_test, Y_test, y_pred_bin, n=3)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 41s 20s/step - accuracy: 0.9179 - loss: 0.2243 - mean_io_u_1: 0.3959
# Test Loss: 0.2345
# Test Accuracy: 0.9138
# Test Mean IoU: 0.3878
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 4s/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.96      0.95    787894
#          1.0       0.86      0.74      0.79    227914
#
#     accuracy                           0.91   1015808
#    macro avg       0.89      0.85      0.87   1015808
# weighted avg       0.91      0.91      0.91   1015808
# Average IoU over test set: 0.5007

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

print("TensorFlow version:", tf.__version__)

try:
    X_selected
    print("Found X_selected in workspace.")
except NameError:
    try:
        best_channels_idx
        X_selected = X[:,:,:,best_channels_idx]
        print("Built X_selected from X and best_channels_idx.")
    except Exception as e:
        raise NameError(
            "X_selected is undefined. Please define it before running cells."
            "For example: X_selected = X[:,:,:,best_channels_idx]"
        )

try:
    Y
except NameError:
    raise NameError("Y(masks) is undefined. Load the masks into the Y variable before continuing.")

print("X_selected shape:", X_selected.shape)
print("Y shape:", Y.shape)
# Out:
# TensorFlow version: 2.19.0
# Found X_selected in workspace.
# X_selected shape: (306, 128, 128, 3)
# Y shape: (306, 128, 128, 1)

# %%
test_frac = 0.15
val_frac = 0.15

X_tmp, X_test, Y_tmp, Y_test = train_test_split(
    X_selected, Y, test_size=test_frac, random_state=42, shuffle=True
)

val_rel = val_frac / (1 - test_frac)
X_train, X_val, Y_train, Y_val = train_test_split(
    X_tmp, Y_tmp, test_size=val_rel, random_state=42, shuffle=True
)

print("Train:", X_train.shape, Y_train.shape)
print("Val:  ", X_val.shape, Y_val.shape)
print("Test: ", X_test.shape, Y_test.shape)
# Out:
# Train: (214, 128, 128, 3) (214, 128, 128, 1)
# Val:   (46, 128, 128, 3) (46, 128, 128, 1)
# Test:  (46, 128, 128, 3) (46, 128, 128, 1)

# %%
from tensorflow.keras import layers, models

def build_unet_resnet50(input_shape=(128,128,3), num_classes=1):
    base_model = tf.keras.applications.ResNet50(
        weights="imagenet", include_top=False, input_shape=input_shape
    )

    skips = [
        base_model.get_layer("conv1_relu").output,        
        base_model.get_layer("conv2_block3_out").output,  
        base_model.get_layer("conv3_block4_out").output,  
        base_model.get_layer("conv4_block6_out").output,  
    ]
    encoder_output = base_model.get_layer("conv5_block3_out").output  

    x = encoder_output
    for skip in reversed(skips):
        x = layers.Conv2DTranspose(256, (3,3), strides=(2,2), padding="same")(x)
        x = layers.Concatenate()([x, skip])
        x = layers.Conv2D(256, (3,3), activation="relu", padding="same")(x)
        x = layers.Conv2D(256, (3,3), activation="relu", padding="same")(x)

    x = layers.Conv2DTranspose(128, (3,3), strides=(2,2), padding="same")(x)
    x = layers.Conv2D(64, (3,3), activation="relu", padding="same")(x)

    outputs = layers.Conv2D(num_classes, (1,1), activation="sigmoid")(x)

    model = models.Model(inputs=base_model.input, outputs=outputs, name="UNet_ResNet50")
    return model

input_shape = X_train.shape[1:]  
model = build_unet_resnet50(input_shape=input_shape, num_classes=1)
model.summary()
# Out:
# Model: "UNet_ResNet50"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 134, 134,  │          0 │ input_layer_8[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 64, 64,    │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 64, 64,    │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 64, 64,    │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 66, 66,    │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 32, 32,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 32, 32,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 32, 32,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 32, 32,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 32, 32,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 32, 32,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 32, 32,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 32, 32,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 32, 32,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 32, 32,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 32, 32,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 32, 32,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 32, 32,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 32, 32,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 32, 32,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 32, 32,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 32, 32,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 32, 32,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 32, 32,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 32, 32,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 32, 32,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 32, 32,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 32, 32,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 32, 32,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 32, 32,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 32, 32,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 32, 32,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 32, 32,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 32, 32,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 32, 32,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 32, 32,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 32, 32,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 32, 32,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 16, 16,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 16, 16,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 16, 16,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 16, 16,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 16, 16,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 16, 16,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 16, 16,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 16, 16,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 16, 16,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 16, 16,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 16, 16,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 16, 16,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 16, 16,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 16, 16,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 16, 16,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 16, 16,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 16, 16,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 16, 16,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 16, 16,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 16, 16,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 16, 16,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 16, 16,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 16, 16,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 16, 16,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 16, 16,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 16, 16,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 16, 16,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 16, 16,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 16, 16,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 16, 16,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 16, 16,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 16, 16,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 16, 16,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 16, 16,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 16, 16,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 16, 16,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 16, 16,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 16, 16,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 16, 16,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 8, 8, 256) │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 8, 8,      │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 8, 8,      │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 8, 8,      │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 8, 8,      │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 8, 8,      │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 8, 8,      │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 8, 8,      │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 8, 8,      │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block4_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block4_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 8, 8,      │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 8, 8,      │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block5_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block5_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 8, 8,      │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 8, 8,      │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 8, 8, 256) │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 8, 8, 256) │          0 │ conv4_block6_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 8, 8, 256) │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 8, 8, 256) │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 8, 8, 256) │          0 │ conv4_block6_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 8, 8,      │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 8, 8,      │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 8, 8,      │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 8, 8,      │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 4, 4, 512) │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 4, 4, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 4, 4, 512) │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 4, 4, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 4, 4,      │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 4, 4,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 4, 4,      │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 4, 4,      │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 4, 4,      │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 4, 4,      │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 4, 4, 512) │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 4, 4, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 4, 4, 512) │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 4, 4, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 4, 4,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 4, 4,      │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 4, 4,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 4, 4,      │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 4, 4, 512) │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 4, 4, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 4, 4, 512) │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 4, 4, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 4, 4, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 4, 4,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 4, 4,      │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 4, 4,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 4, 4,      │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 8, 8, 256) │  4,718,848 │ conv5_block3_out… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 8, 8,      │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1280)             │            │ conv4_block6_out… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 8, 8, 256) │  2,949,376 │ concatenate_10[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ conv2d_43[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 16, 16,    │    590,080 │ conv2d_44[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 768)              │            │ conv3_block4_out… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 16, 16,    │  1,769,728 │ concatenate_11[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 16, 16,    │    590,080 │ conv2d_45[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 32, 32,    │    590,080 │ conv2d_46[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2_block3_out… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate_12[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 32, 32,    │    590,080 │ conv2d_47[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (None, 64, 64,    │    590,080 │ conv2d_48[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 320)              │            │ conv1_relu[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 64, 64,    │    737,536 │ concatenate_13[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_49[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_9  │ (None, 128, 128,  │    295,040 │ conv2d_50[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 128, 128,  │     73,792 │ conv2d_transpose… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 128, 128,  │         65 │ conv2d_51[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 39,442,561 (150.46 MB)
#  Trainable params: 39,389,441 (150.26 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
from tensorflow.keras.optimizers import Adam

def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return 1.0 - (2.0 * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    bce = tf.reduce_mean(bce)
    return bce + dice_loss(y_true, y_pred)

try:
    optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-4)
except Exception:
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)  

model.compile(
    optimizer=optimizer,
    loss=bce_dice_loss,
    metrics=["binary_accuracy", tf.keras.metrics.MeanIoU(num_classes=2)]
)

print("Compiled model with BCE + Dice loss and AdamW (or Adam fallback).")
# Out:
# Compiled model with BCE + Dice loss and AdamW (or Adam fallback).

# %%
AUTOTUNE = tf.data.AUTOTUNE
batch_size = 8

preprocess_fn = tf.keras.applications.resnet.preprocess_input  

def augment_and_preprocess(image, mask):
    image = tf.cast(image, tf.float32)
    mask = tf.cast(mask, tf.float32)

    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    if tf.random.uniform(()) > 0.5:
        k = tf.random.uniform((), minval=0, maxval=4, dtype=tf.int32)
        image = tf.image.rot90(image, k)
        mask = tf.image.rot90(mask, k)

    if tf.random.uniform(()) > 0.5:
        image = tf.image.random_brightness(image, max_delta=0.15)

    if tf.random.uniform(()) > 0.7:
        noise = tf.random.normal(shape=tf.shape(image), mean=0.0, stddev=0.01)
        image = image + noise

    image = image * 255.0
    image = preprocess_fn(image)

    return image, mask

def preprocess_only(image, mask):
    image = tf.cast(image, tf.float32)
    mask = tf.cast(mask, tf.float32)
    image = image * 255.0
    image = preprocess_fn(image)
    return image, mask

# Build datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
train_ds = train_ds.shuffle(2048, seed=42).map(augment_and_preprocess, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.batch(batch_size).prefetch(AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((X_val, Y_val))
val_ds = val_ds.map(preprocess_only, num_parallel_calls=AUTOTUNE).batch(batch_size).prefetch(AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
test_ds = test_ds.map(preprocess_only, num_parallel_calls=AUTOTUNE).batch(batch_size).prefetch(AUTOTUNE)

print("Datasets ready: train/val/test")
# Out:
# Datasets ready: train/val/test

# %%
checkpoint_path = "resnet50.keras"

callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True, verbose=1),
    #tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, verbose=1),
    tf.keras.callbacks.ModelCheckpoint(checkpoint_path, monitor="val_binary_accuracy", save_best_only=True, verbose=1)
]

print("Callbacks set. Saving best model to:", checkpoint_path)
# Out:
# Callbacks set. Saving best model to: resnet50.keras

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.8822 - loss: 0.5552 - mean_io_u_2: 0.3573
# Epoch 1: val_binary_accuracy improved from -inf to 0.90475, saving model to resnet50.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 23s 854ms/step - binary_accuracy: 0.8821 - loss: 0.5561 - mean_io_u_2: 0.3575 - val_binary_accuracy: 0.9048 - val_loss: 0.5582 - val_mean_io_u_2: 0.3730
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.8961 - loss: 0.5568 - mean_io_u_2: 0.3793
# Epoch 2: val_binary_accuracy did not improve from 0.90475
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - binary_accuracy: 0.8959 - loss: 0.5561 - mean_io_u_2: 0.3787 - val_binary_accuracy: 0.9005 - val_loss: 0.5721 - val_mean_io_u_2: 0.3730
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.8815 - loss: 0.5541 - mean_io_u_2: 0.3651
# Epoch 3: val_binary_accuracy did not improve from 0.90475
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - binary_accuracy: 0.8817 - loss: 0.5530 - mean_io_u_2: 0.3650 - val_binary_accuracy: 0.8899 - val_loss: 0.6947 - val_mean_io_u_2: 0.4167
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - binary_accuracy: 0.8897 - loss: 0.5690 - mean_io_u_2: 0.3732
# Epoch 4: val_binary_accuracy did not improve from 0.90475
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - binary_accuracy: 0.8896 - loss: 0.5681 - mean_io_u_2: 0.3728 - val_binary_accuracy: 0.9028 - val_loss: 0.5935 - val_mean_io_u_2: 0.4198
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.8787 - loss: 0.5458 - mean_io_u_2: 0.3464
# Epoch 5: val_binary_accuracy did not improve from 0.90475
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - binary_accuracy: 0.8792 - loss: 0.5448 - mean_io_u_2: 0.3470 - val_binary_accuracy: 0.8806 - val_loss: 0.6595 - val_mean_io_u_2: 0.4192
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.8810 - loss: 0.5853 - mean_io_u_2: 0.3674
# Epoch 6: val_binary_accuracy did not improve from 0.90475
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - binary_accuracy: 0.8810 - loss: 0.5854 - mean_io_u_2: 0.3672 - val_binary_accuracy: 0.8868 - val_loss: 0.6912 - val_mean_io_u_2: 0.4157
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - binary_accuracy: 0.8908 - loss: 0.5381 - mean_io_u_2: 0.3637
# Epoch 7: val_binary_accuracy did not improve from 0.90475
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - binary_accuracy: 0.8908 - loss: 0.5381 - mean_io_u_2: 0.3637 - val_binary_accuracy: 0.8679 - val_loss: 0.6660 - val_mean_io_u_2: 0.4105
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.8968 - loss: 0.5174 - mean_io_u_2: 0.3696
# Epoch 8: val_binary_accuracy did not improve from 0.90475
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - binary_accuracy: 0.8964 - loss: 0.5185 - mean_io_u_2: 0.3693 - val_binary_accuracy: 0.8846 - val_loss: 0.7283 - val_mean_io_u_2: 0.3920
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.8997 - loss: 0.5276 - mean_io_u_2: 0.3794
# Epoch 9: val_binary_accuracy did not improve from 0.90475
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - binary_accuracy: 0.8995 - loss: 0.5273 - mean_io_u_2: 0.3788 - val_binary_accuracy: 0.8970 - val_loss: 0.5721 - val_mean_io_u_2: 0.4213
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.8986 - loss: 0.4736 - mean_io_u_2: 0.3572
# Epoch 10: val_binary_accuracy did not improve from 0.90475
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - binary_accuracy: 0.8987 - loss: 0.4741 - mean_io_u_2: 0.3574 - val_binary_accuracy: 0.9006 - val_loss: 0.5541 - val_mean_io_u_2: 0.4026
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.8965 - loss: 0.4863 - mean_io_u_2: 0.3471
# Epoch 11: val_binary_accuracy did not improve from 0.90475
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 212ms/step - binary_accuracy: 0.8966 - loss: 0.4865 - mean_io_u_2: 0.3476 - val_binary_accuracy: 0.8893 - val_loss: 0.6090 - val_mean_io_u_2: 0.3789
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - binary_accuracy: 0.9015 - loss: 0.4776 - mean_io_u_2: 0.3563
# Epoch 12: val_binary_accuracy did not improve from 0.90475
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - binary_accuracy: 0.9014 - loss: 0.4784 - mean_io_u_2: 0.3566 - val_binary_accuracy: 0.8886 - val_loss: 0.6153 - val_mean_io_u_2: 0.3730
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.8988 - loss: 0.4603 - mean_io_u_2: 0.3460
# Epoch 13: val_binary_accuracy did not improve from 0.90475
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 208ms/step - binary_accuracy: 0.8991 - loss: 0.4596 - mean_io_u_2: 0.3465 - val_binary_accuracy: 0.8936 - val_loss: 0.5824 - val_mean_io_u_2: 0.3730
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - binary_accuracy: 0.9014 - loss: 0.4887 - mean_io_u_2: 0.3663
# Epoch 14: val_binary_accuracy improved from 0.90475 to 0.90563, saving model to resnet50.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 23s 864ms/step - binary_accuracy: 0.9014 - loss: 0.4887 - mean_io_u_2: 0.3662 - val_binary_accuracy: 0.9056 - val_loss: 0.5373 - val_mean_io_u_2: 0.3758
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.9007 - loss: 0.4710 - mean_io_u_2: 0.3537
# Epoch 15: val_binary_accuracy did not improve from 0.90563
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - binary_accuracy: 0.9009 - loss: 0.4706 - mean_io_u_2: 0.3540 - val_binary_accuracy: 0.8914 - val_loss: 0.5799 - val_mean_io_u_2: 0.3822
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - binary_accuracy: 0.9047 - loss: 0.4509 - mean_io_u_2: 0.3610
# Epoch 16: val_binary_accuracy did not improve from 0.90563
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - binary_accuracy: 0.9047 - loss: 0.4510 - mean_io_u_2: 0.3610 - val_binary_accuracy: 0.8839 - val_loss: 0.5965 - val_mean_io_u_2: 0.4093
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - binary_accuracy: 0.9074 - loss: 0.4419 - mean_io_u_2: 0.3475
# Epoch 17: val_binary_accuracy did not improve from 0.90563
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - binary_accuracy: 0.9073 - loss: 0.4432 - mean_io_u_2: 0.3480 - val_binary_accuracy: 0.8681 - val_loss: 0.6662 - val_mean_io_u_2: 0.3730
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9044 - loss: 0.4733 - mean_io_u_2: 0.3668
# Epoch 18: val_binary_accuracy did not improve from 0.90563
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - binary_accuracy: 0.9044 - loss: 0.4730 - mean_io_u_2: 0.3667 - val_binary_accuracy: 0.8875 - val_loss: 0.5868 - val_mean_io_u_2: 0.3733
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - binary_accuracy: 0.9118 - loss: 0.4420 - mean_io_u_2: 0.3629
# Epoch 19: val_binary_accuracy did not improve from 0.90563
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - binary_accuracy: 0.9117 - loss: 0.4421 - mean_io_u_2: 0.3629 - val_binary_accuracy: 0.8830 - val_loss: 0.6062 - val_mean_io_u_2: 0.4214
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - binary_accuracy: 0.9143 - loss: 0.4193 - mean_io_u_2: 0.3629
# Epoch 20: val_binary_accuracy did not improve from 0.90563
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - binary_accuracy: 0.9142 - loss: 0.4193 - mean_io_u_2: 0.3629 - val_binary_accuracy: 0.9001 - val_loss: 0.5503 - val_mean_io_u_2: 0.3876
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9081 - loss: 0.4331 - mean_io_u_2: 0.3557
# Epoch 21: val_binary_accuracy improved from 0.90563 to 0.90638, saving model to resnet50.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 23s 885ms/step - binary_accuracy: 0.9082 - loss: 0.4327 - mean_io_u_2: 0.3560 - val_binary_accuracy: 0.9064 - val_loss: 0.5834 - val_mean_io_u_2: 0.4225
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - binary_accuracy: 0.9115 - loss: 0.4467 - mean_io_u_2: 0.3694
# Epoch 22: val_binary_accuracy did not improve from 0.90638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - binary_accuracy: 0.9115 - loss: 0.4466 - mean_io_u_2: 0.3692 - val_binary_accuracy: 0.9042 - val_loss: 0.5637 - val_mean_io_u_2: 0.4270
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - binary_accuracy: 0.9164 - loss: 0.4337 - mean_io_u_2: 0.3626
# Epoch 23: val_binary_accuracy did not improve from 0.90638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - binary_accuracy: 0.9165 - loss: 0.4333 - mean_io_u_2: 0.3626 - val_binary_accuracy: 0.9061 - val_loss: 0.5710 - val_mean_io_u_2: 0.3810
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9253 - loss: 0.3985 - mean_io_u_2: 0.3814
# Epoch 24: val_binary_accuracy did not improve from 0.90638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - binary_accuracy: 0.9250 - loss: 0.3992 - mean_io_u_2: 0.3808 - val_binary_accuracy: 0.9014 - val_loss: 0.5380 - val_mean_io_u_2: 0.4116
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9218 - loss: 0.3710 - mean_io_u_2: 0.3494
# Epoch 25: val_binary_accuracy improved from 0.90638 to 0.91110, saving model to resnet50.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 21s 808ms/step - binary_accuracy: 0.9218 - loss: 0.3719 - mean_io_u_2: 0.3498 - val_binary_accuracy: 0.9111 - val_loss: 0.4932 - val_mean_io_u_2: 0.3730
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.9228 - loss: 0.3815 - mean_io_u_2: 0.3563
# Epoch 26: val_binary_accuracy did not improve from 0.91110
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - binary_accuracy: 0.9228 - loss: 0.3819 - mean_io_u_2: 0.3565 - val_binary_accuracy: 0.9075 - val_loss: 0.4936 - val_mean_io_u_2: 0.3730
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - binary_accuracy: 0.9205 - loss: 0.3962 - mean_io_u_2: 0.3583
# Epoch 27: val_binary_accuracy did not improve from 0.91110
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - binary_accuracy: 0.9206 - loss: 0.3961 - mean_io_u_2: 0.3585 - val_binary_accuracy: 0.8854 - val_loss: 0.5586 - val_mean_io_u_2: 0.3731
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - binary_accuracy: 0.9087 - loss: 0.4178 - mean_io_u_2: 0.3506
# Epoch 28: val_binary_accuracy did not improve from 0.91110
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - binary_accuracy: 0.9092 - loss: 0.4159 - mean_io_u_2: 0.3510 - val_binary_accuracy: 0.9049 - val_loss: 0.5193 - val_mean_io_u_2: 0.3730
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - binary_accuracy: 0.9153 - loss: 0.4357 - mean_io_u_2: 0.3662
# Epoch 29: val_binary_accuracy did not improve from 0.91110
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - binary_accuracy: 0.9155 - loss: 0.4348 - mean_io_u_2: 0.3661 - val_binary_accuracy: 0.8961 - val_loss: 0.5845 - val_mean_io_u_2: 0.3730
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9260 - loss: 0.3608 - mean_io_u_2: 0.3646
# Epoch 30: val_binary_accuracy did not improve from 0.91110
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - binary_accuracy: 0.9258 - loss: 0.3613 - mean_io_u_2: 0.3645 - val_binary_accuracy: 0.9068 - val_loss: 0.5738 - val_mean_io_u_2: 0.4026
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.9258 - loss: 0.3652 - mean_io_u_2: 0.3559
# Epoch 31: val_binary_accuracy did not improve from 0.91110
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - binary_accuracy: 0.9258 - loss: 0.3657 - mean_io_u_2: 0.3561 - val_binary_accuracy: 0.9104 - val_loss: 0.5156 - val_mean_io_u_2: 0.3730
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9275 - loss: 0.3704 - mean_io_u_2: 0.3675
# Epoch 32: val_binary_accuracy did not improve from 0.91110
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - binary_accuracy: 0.9274 - loss: 0.3707 - mean_io_u_2: 0.3673 - val_binary_accuracy: 0.8799 - val_loss: 0.6160 - val_mean_io_u_2: 0.4295
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.9165 - loss: 0.3976 - mean_io_u_2: 0.3566
# Epoch 33: val_binary_accuracy improved from 0.91110 to 0.92166, saving model to resnet50.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 15s 560ms/step - binary_accuracy: 0.9168 - loss: 0.3965 - mean_io_u_2: 0.3568 - val_binary_accuracy: 0.9217 - val_loss: 0.4552 - val_mean_io_u_2: 0.3730
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9130 - loss: 0.4261 - mean_io_u_2: 0.3527
# Epoch 34: val_binary_accuracy did not improve from 0.92166
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - binary_accuracy: 0.9134 - loss: 0.4246 - mean_io_u_2: 0.3531 - val_binary_accuracy: 0.9195 - val_loss: 0.4820 - val_mean_io_u_2: 0.3730
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - binary_accuracy: 0.9390 - loss: 0.3470 - mean_io_u_2: 0.3764
# Epoch 35: val_binary_accuracy did not improve from 0.92166
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - binary_accuracy: 0.9386 - loss: 0.3476 - mean_io_u_2: 0.3759 - val_binary_accuracy: 0.9002 - val_loss: 0.5158 - val_mean_io_u_2: 0.4070
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9259 - loss: 0.3964 - mean_io_u_2: 0.3578
# Epoch 36: val_binary_accuracy did not improve from 0.92166
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - binary_accuracy: 0.9259 - loss: 0.3965 - mean_io_u_2: 0.3579 - val_binary_accuracy: 0.9207 - val_loss: 0.4500 - val_mean_io_u_2: 0.3732
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9423 - loss: 0.3057 - mean_io_u_2: 0.3661
# Epoch 37: val_binary_accuracy did not improve from 0.92166
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - binary_accuracy: 0.9418 - loss: 0.3073 - mean_io_u_2: 0.3660 - val_binary_accuracy: 0.9137 - val_loss: 0.4855 - val_mean_io_u_2: 0.3730
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - binary_accuracy: 0.9315 - loss: 0.3497 - mean_io_u_2: 0.3618
# Epoch 38: val_binary_accuracy did not improve from 0.92166
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 210ms/step - binary_accuracy: 0.9315 - loss: 0.3499 - mean_io_u_2: 0.3618 - val_binary_accuracy: 0.9083 - val_loss: 0.4902 - val_mean_io_u_2: 0.3730
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9375 - loss: 0.3157 - mean_io_u_2: 0.3685
# Epoch 39: val_binary_accuracy did not improve from 0.92166
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 195ms/step - binary_accuracy: 0.9373 - loss: 0.3165 - mean_io_u_2: 0.3683 - val_binary_accuracy: 0.8950 - val_loss: 0.5388 - val_mean_io_u_2: 0.3922
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - binary_accuracy: 0.9215 - loss: 0.3814 - mean_io_u_2: 0.3598
# Epoch 40: val_binary_accuracy did not improve from 0.92166
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - binary_accuracy: 0.9220 - loss: 0.3799 - mean_io_u_2: 0.3599 - val_binary_accuracy: 0.9160 - val_loss: 0.4808 - val_mean_io_u_2: 0.3989
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9296 - loss: 0.3432 - mean_io_u_2: 0.3444
# Epoch 41: val_binary_accuracy improved from 0.92166 to 0.92465, saving model to resnet50.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - binary_accuracy: 0.9299 - loss: 0.3428 - mean_io_u_2: 0.3451 - val_binary_accuracy: 0.9247 - val_loss: 0.4665 - val_mean_io_u_2: 0.3730
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9392 - loss: 0.3287 - mean_io_u_2: 0.3701
# Epoch 42: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 199ms/step - binary_accuracy: 0.9389 - loss: 0.3298 - mean_io_u_2: 0.3698 - val_binary_accuracy: 0.9033 - val_loss: 0.5520 - val_mean_io_u_2: 0.3751
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.9267 - loss: 0.3491 - mean_io_u_2: 0.3448
# Epoch 43: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - binary_accuracy: 0.9269 - loss: 0.3489 - mean_io_u_2: 0.3454 - val_binary_accuracy: 0.9165 - val_loss: 0.4909 - val_mean_io_u_2: 0.3730
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - binary_accuracy: 0.9234 - loss: 0.3875 - mean_io_u_2: 0.3542
# Epoch 44: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - binary_accuracy: 0.9236 - loss: 0.3866 - mean_io_u_2: 0.3546 - val_binary_accuracy: 0.9184 - val_loss: 0.4721 - val_mean_io_u_2: 0.3750
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9339 - loss: 0.3343 - mean_io_u_2: 0.3457
# Epoch 45: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - binary_accuracy: 0.9340 - loss: 0.3344 - mean_io_u_2: 0.3463 - val_binary_accuracy: 0.9009 - val_loss: 0.5420 - val_mean_io_u_2: 0.3746
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.9418 - loss: 0.3102 - mean_io_u_2: 0.3671
# Epoch 46: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - binary_accuracy: 0.9416 - loss: 0.3108 - mean_io_u_2: 0.3669 - val_binary_accuracy: 0.9192 - val_loss: 0.4967 - val_mean_io_u_2: 0.3730
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - binary_accuracy: 0.9369 - loss: 0.3329 - mean_io_u_2: 0.3686
# Epoch 47: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 196ms/step - binary_accuracy: 0.9369 - loss: 0.3330 - mean_io_u_2: 0.3684 - val_binary_accuracy: 0.9137 - val_loss: 0.5259 - val_mean_io_u_2: 0.3749
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - binary_accuracy: 0.9371 - loss: 0.3238 - mean_io_u_2: 0.3672
# Epoch 48: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - binary_accuracy: 0.9370 - loss: 0.3237 - mean_io_u_2: 0.3670 - val_binary_accuracy: 0.9077 - val_loss: 0.5212 - val_mean_io_u_2: 0.3730
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9403 - loss: 0.3059 - mean_io_u_2: 0.3663
# Epoch 49: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - binary_accuracy: 0.9402 - loss: 0.3062 - mean_io_u_2: 0.3661 - val_binary_accuracy: 0.9067 - val_loss: 0.4883 - val_mean_io_u_2: 0.3934
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - binary_accuracy: 0.9344 - loss: 0.3195 - mean_io_u_2: 0.3565
# Epoch 50: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - binary_accuracy: 0.9346 - loss: 0.3189 - mean_io_u_2: 0.3567 - val_binary_accuracy: 0.9052 - val_loss: 0.5286 - val_mean_io_u_2: 0.3738
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - binary_accuracy: 0.9390 - loss: 0.3017 - mean_io_u_2: 0.3566
# Epoch 51: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - binary_accuracy: 0.9391 - loss: 0.3019 - mean_io_u_2: 0.3568 - val_binary_accuracy: 0.8955 - val_loss: 0.5291 - val_mean_io_u_2: 0.3770
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9396 - loss: 0.3002 - mean_io_u_2: 0.3690
# Epoch 52: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - binary_accuracy: 0.9397 - loss: 0.3000 - mean_io_u_2: 0.3687 - val_binary_accuracy: 0.9078 - val_loss: 0.4826 - val_mean_io_u_2: 0.4167
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.9474 - loss: 0.2870 - mean_io_u_2: 0.3728
# Epoch 53: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - binary_accuracy: 0.9472 - loss: 0.2875 - mean_io_u_2: 0.3726 - val_binary_accuracy: 0.9160 - val_loss: 0.4577 - val_mean_io_u_2: 0.4158
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.9456 - loss: 0.2856 - mean_io_u_2: 0.3672
# Epoch 54: val_binary_accuracy did not improve from 0.92465
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 209ms/step - binary_accuracy: 0.9456 - loss: 0.2853 - mean_io_u_2: 0.3670 - val_binary_accuracy: 0.9197 - val_loss: 0.4620 - val_mean_io_u_2: 0.4096
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.9373 - loss: 0.3105 - mean_io_u_2: 0.3525
# Epoch 55: val_binary_accuracy improved from 0.92465 to 0.92628, saving model to resnet50.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - binary_accuracy: 0.9374 - loss: 0.3103 - mean_io_u_2: 0.3529 - val_binary_accuracy: 0.9263 - val_loss: 0.4742 - val_mean_io_u_2: 0.4185
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.9476 - loss: 0.2743 - mean_io_u_2: 0.3659
# Epoch 56: val_binary_accuracy did not improve from 0.92628
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step - binary_accuracy: 0.9475 - loss: 0.2745 - mean_io_u_2: 0.3658 - val_binary_accuracy: 0.9202 - val_loss: 0.5240 - val_mean_io_u_2: 0.3743
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9419 - loss: 0.2818 - mean_io_u_2: 0.3568
# Epoch 57: val_binary_accuracy did not improve from 0.92628
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - binary_accuracy: 0.9420 - loss: 0.2820 - mean_io_u_2: 0.3570 - val_binary_accuracy: 0.8975 - val_loss: 0.5426 - val_mean_io_u_2: 0.4262
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - binary_accuracy: 0.9477 - loss: 0.2658 - mean_io_u_2: 0.3733
# Epoch 58: val_binary_accuracy did not improve from 0.92628
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 203ms/step - binary_accuracy: 0.9476 - loss: 0.2662 - mean_io_u_2: 0.3730 - val_binary_accuracy: 0.9227 - val_loss: 0.4445 - val_mean_io_u_2: 0.4208
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9428 - loss: 0.2730 - mean_io_u_2: 0.3480
# Epoch 59: val_binary_accuracy did not improve from 0.92628
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - binary_accuracy: 0.9430 - loss: 0.2729 - mean_io_u_2: 0.3486 - val_binary_accuracy: 0.9159 - val_loss: 0.4630 - val_mean_io_u_2: 0.4239
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.9505 - loss: 0.2557 - mean_io_u_2: 0.3727
# Epoch 60: val_binary_accuracy improved from 0.92628 to 0.92638, saving model to resnet50.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - binary_accuracy: 0.9504 - loss: 0.2561 - mean_io_u_2: 0.3725 - val_binary_accuracy: 0.9264 - val_loss: 0.4223 - val_mean_io_u_2: 0.4161
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.9469 - loss: 0.2697 - mean_io_u_2: 0.3555
# Epoch 61: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - binary_accuracy: 0.9469 - loss: 0.2693 - mean_io_u_2: 0.3558 - val_binary_accuracy: 0.9181 - val_loss: 0.4615 - val_mean_io_u_2: 0.4229
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9479 - loss: 0.2649 - mean_io_u_2: 0.3547
# Epoch 62: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - binary_accuracy: 0.9479 - loss: 0.2648 - mean_io_u_2: 0.3550 - val_binary_accuracy: 0.9217 - val_loss: 0.4815 - val_mean_io_u_2: 0.4223
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - binary_accuracy: 0.9485 - loss: 0.2771 - mean_io_u_2: 0.3662
# Epoch 63: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - binary_accuracy: 0.9485 - loss: 0.2769 - mean_io_u_2: 0.3661 - val_binary_accuracy: 0.9257 - val_loss: 0.4394 - val_mean_io_u_2: 0.4005
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9577 - loss: 0.2222 - mean_io_u_2: 0.3700
# Epoch 64: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - binary_accuracy: 0.9574 - loss: 0.2229 - mean_io_u_2: 0.3698 - val_binary_accuracy: 0.9234 - val_loss: 0.4452 - val_mean_io_u_2: 0.4125
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - binary_accuracy: 0.9484 - loss: 0.2656 - mean_io_u_2: 0.3598
# Epoch 65: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 202ms/step - binary_accuracy: 0.9485 - loss: 0.2648 - mean_io_u_2: 0.3599 - val_binary_accuracy: 0.9189 - val_loss: 0.4983 - val_mean_io_u_2: 0.4230
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9444 - loss: 0.2644 - mean_io_u_2: 0.3449
# Epoch 66: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - binary_accuracy: 0.9447 - loss: 0.2639 - mean_io_u_2: 0.3457 - val_binary_accuracy: 0.9132 - val_loss: 0.4859 - val_mean_io_u_2: 0.4232
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9476 - loss: 0.3004 - mean_io_u_2: 0.3873
# Epoch 67: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - binary_accuracy: 0.9477 - loss: 0.2991 - mean_io_u_2: 0.3865 - val_binary_accuracy: 0.9095 - val_loss: 0.5097 - val_mean_io_u_2: 0.4208
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.9508 - loss: 0.2517 - mean_io_u_2: 0.3666
# Epoch 68: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 194ms/step - binary_accuracy: 0.9508 - loss: 0.2516 - mean_io_u_2: 0.3666 - val_binary_accuracy: 0.9256 - val_loss: 0.4567 - val_mean_io_u_2: 0.4168
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.9501 - loss: 0.2711 - mean_io_u_2: 0.3751
# Epoch 69: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - binary_accuracy: 0.9501 - loss: 0.2705 - mean_io_u_2: 0.3748 - val_binary_accuracy: 0.9235 - val_loss: 0.4858 - val_mean_io_u_2: 0.4191
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.9611 - loss: 0.2009 - mean_io_u_2: 0.3710
# Epoch 70: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - binary_accuracy: 0.9609 - loss: 0.2019 - mean_io_u_2: 0.3708 - val_binary_accuracy: 0.9249 - val_loss: 0.4470 - val_mean_io_u_2: 0.4208
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.9548 - loss: 0.2624 - mean_io_u_2: 0.3878
# Epoch 71: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - binary_accuracy: 0.9548 - loss: 0.2614 - mean_io_u_2: 0.3870 - val_binary_accuracy: 0.9260 - val_loss: 0.4431 - val_mean_io_u_2: 0.4222
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9595 - loss: 0.2061 - mean_io_u_2: 0.3739
# Epoch 72: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - binary_accuracy: 0.9594 - loss: 0.2066 - mean_io_u_2: 0.3736 - val_binary_accuracy: 0.9237 - val_loss: 0.4616 - val_mean_io_u_2: 0.4162
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9595 - loss: 0.2173 - mean_io_u_2: 0.3756
# Epoch 73: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 202ms/step - binary_accuracy: 0.9594 - loss: 0.2174 - mean_io_u_2: 0.3752 - val_binary_accuracy: 0.9202 - val_loss: 0.4770 - val_mean_io_u_2: 0.4211
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - binary_accuracy: 0.9553 - loss: 0.2389 - mean_io_u_2: 0.3657
# Epoch 74: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step - binary_accuracy: 0.9553 - loss: 0.2384 - mean_io_u_2: 0.3656 - val_binary_accuracy: 0.9113 - val_loss: 0.5913 - val_mean_io_u_2: 0.4214
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.9547 - loss: 0.2294 - mean_io_u_2: 0.3522
# Epoch 75: val_binary_accuracy did not improve from 0.92638
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step - binary_accuracy: 0.9547 - loss: 0.2297 - mean_io_u_2: 0.3526 - val_binary_accuracy: 0.9125 - val_loss: 0.5253 - val_mean_io_u_2: 0.4214
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9563 - loss: 0.2248 - mean_io_u_2: 0.3609
# Epoch 76: val_binary_accuracy improved from 0.92638 to 0.92771, saving model to resnet50.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 22s 830ms/step - binary_accuracy: 0.9563 - loss: 0.2247 - mean_io_u_2: 0.3610 - val_binary_accuracy: 0.9277 - val_loss: 0.4270 - val_mean_io_u_2: 0.4285
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9564 - loss: 0.2399 - mean_io_u_2: 0.3686
# Epoch 77: val_binary_accuracy improved from 0.92771 to 0.93056, saving model to resnet50.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - binary_accuracy: 0.9564 - loss: 0.2396 - mean_io_u_2: 0.3684 - val_binary_accuracy: 0.9306 - val_loss: 0.4070 - val_mean_io_u_2: 0.4249
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - binary_accuracy: 0.9599 - loss: 0.2089 - mean_io_u_2: 0.3732
# Epoch 78: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step - binary_accuracy: 0.9598 - loss: 0.2095 - mean_io_u_2: 0.3730 - val_binary_accuracy: 0.9247 - val_loss: 0.4480 - val_mean_io_u_2: 0.4291
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9569 - loss: 0.2398 - mean_io_u_2: 0.3777
# Epoch 79: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - binary_accuracy: 0.9569 - loss: 0.2397 - mean_io_u_2: 0.3773 - val_binary_accuracy: 0.9053 - val_loss: 0.6128 - val_mean_io_u_2: 0.4458
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - binary_accuracy: 0.9404 - loss: 0.3687 - mean_io_u_2: 0.3648
# Epoch 80: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 202ms/step - binary_accuracy: 0.9406 - loss: 0.3665 - mean_io_u_2: 0.3648 - val_binary_accuracy: 0.9220 - val_loss: 0.4769 - val_mean_io_u_2: 0.4242
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - binary_accuracy: 0.9534 - loss: 0.2333 - mean_io_u_2: 0.3576
# Epoch 81: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - binary_accuracy: 0.9534 - loss: 0.2335 - mean_io_u_2: 0.3578 - val_binary_accuracy: 0.9245 - val_loss: 0.4770 - val_mean_io_u_2: 0.4127
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - binary_accuracy: 0.9510 - loss: 0.2505 - mean_io_u_2: 0.3531
# Epoch 82: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - binary_accuracy: 0.9510 - loss: 0.2507 - mean_io_u_2: 0.3534 - val_binary_accuracy: 0.9121 - val_loss: 0.6145 - val_mean_io_u_2: 0.3733
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.9564 - loss: 0.2479 - mean_io_u_2: 0.3772
# Epoch 83: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 202ms/step - binary_accuracy: 0.9564 - loss: 0.2472 - mean_io_u_2: 0.3767 - val_binary_accuracy: 0.9127 - val_loss: 0.5652 - val_mean_io_u_2: 0.3893
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - binary_accuracy: 0.9606 - loss: 0.2170 - mean_io_u_2: 0.3789
# Epoch 84: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 194ms/step - binary_accuracy: 0.9605 - loss: 0.2172 - mean_io_u_2: 0.3783 - val_binary_accuracy: 0.9122 - val_loss: 0.5188 - val_mean_io_u_2: 0.4023
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - binary_accuracy: 0.9614 - loss: 0.1968 - mean_io_u_2: 0.3556
# Epoch 85: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - binary_accuracy: 0.9613 - loss: 0.1971 - mean_io_u_2: 0.3559 - val_binary_accuracy: 0.9199 - val_loss: 0.4904 - val_mean_io_u_2: 0.4135
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - binary_accuracy: 0.9587 - loss: 0.2079 - mean_io_u_2: 0.3614
# Epoch 86: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - binary_accuracy: 0.9587 - loss: 0.2081 - mean_io_u_2: 0.3615 - val_binary_accuracy: 0.9268 - val_loss: 0.4232 - val_mean_io_u_2: 0.4079
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - binary_accuracy: 0.9527 - loss: 0.2509 - mean_io_u_2: 0.3582
# Epoch 87: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - binary_accuracy: 0.9527 - loss: 0.2509 - mean_io_u_2: 0.3583 - val_binary_accuracy: 0.8059 - val_loss: 1.0251 - val_mean_io_u_2: 0.4358
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - binary_accuracy: 0.9553 - loss: 0.2269 - mean_io_u_2: 0.3529
# Epoch 88: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - binary_accuracy: 0.9553 - loss: 0.2273 - mean_io_u_2: 0.3533 - val_binary_accuracy: 0.8910 - val_loss: 0.6762 - val_mean_io_u_2: 0.4951
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9550 - loss: 0.2253 - mean_io_u_2: 0.3591
# Epoch 89: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 195ms/step - binary_accuracy: 0.9550 - loss: 0.2255 - mean_io_u_2: 0.3593 - val_binary_accuracy: 0.9288 - val_loss: 0.4013 - val_mean_io_u_2: 0.3904
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - binary_accuracy: 0.9552 - loss: 0.2285 - mean_io_u_2: 0.3462
# Epoch 90: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 210ms/step - binary_accuracy: 0.9553 - loss: 0.2285 - mean_io_u_2: 0.3468 - val_binary_accuracy: 0.8839 - val_loss: 0.6175 - val_mean_io_u_2: 0.3742
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - binary_accuracy: 0.9531 - loss: 0.2420 - mean_io_u_2: 0.3706
# Epoch 91: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - binary_accuracy: 0.9531 - loss: 0.2417 - mean_io_u_2: 0.3703 - val_binary_accuracy: 0.8440 - val_loss: 0.8043 - val_mean_io_u_2: 0.4445
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.9161 - loss: 0.4550 - mean_io_u_2: 0.3754
# Epoch 92: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 202ms/step - binary_accuracy: 0.9165 - loss: 0.4525 - mean_io_u_2: 0.3750 - val_binary_accuracy: 0.9162 - val_loss: 0.4856 - val_mean_io_u_2: 0.3891
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.9444 - loss: 0.2928 - mean_io_u_2: 0.3522
# Epoch 93: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step - binary_accuracy: 0.9446 - loss: 0.2921 - mean_io_u_2: 0.3526 - val_binary_accuracy: 0.9186 - val_loss: 0.4637 - val_mean_io_u_2: 0.4072
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - binary_accuracy: 0.9494 - loss: 0.2596 - mean_io_u_2: 0.3550
# Epoch 94: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - binary_accuracy: 0.9495 - loss: 0.2599 - mean_io_u_2: 0.3553 - val_binary_accuracy: 0.9125 - val_loss: 0.4570 - val_mean_io_u_2: 0.3736
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - binary_accuracy: 0.9498 - loss: 0.2692 - mean_io_u_2: 0.3607
# Epoch 95: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - binary_accuracy: 0.9495 - loss: 0.2710 - mean_io_u_2: 0.3608 - val_binary_accuracy: 0.7993 - val_loss: 1.0717 - val_mean_io_u_2: 0.3752
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - binary_accuracy: 0.9439 - loss: 0.2945 - mean_io_u_2: 0.3651
# Epoch 96: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - binary_accuracy: 0.9440 - loss: 0.2944 - mean_io_u_2: 0.3650 - val_binary_accuracy: 0.8025 - val_loss: 0.9789 - val_mean_io_u_2: 0.3730
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - binary_accuracy: 0.9518 - loss: 0.2537 - mean_io_u_2: 0.3663
# Epoch 97: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - binary_accuracy: 0.9517 - loss: 0.2544 - mean_io_u_2: 0.3661 - val_binary_accuracy: 0.8582 - val_loss: 0.7404 - val_mean_io_u_2: 0.4203
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9539 - loss: 0.2423 - mean_io_u_2: 0.3646
# Epoch 98: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - binary_accuracy: 0.9538 - loss: 0.2427 - mean_io_u_2: 0.3645 - val_binary_accuracy: 0.9010 - val_loss: 0.5214 - val_mean_io_u_2: 0.4209
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - binary_accuracy: 0.9525 - loss: 0.2762 - mean_io_u_2: 0.3678
# Epoch 99: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - binary_accuracy: 0.9525 - loss: 0.2752 - mean_io_u_2: 0.3676 - val_binary_accuracy: 0.9219 - val_loss: 0.4691 - val_mean_io_u_2: 0.4198
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - binary_accuracy: 0.9557 - loss: 0.2220 - mean_io_u_2: 0.3560
# Epoch 100: val_binary_accuracy did not improve from 0.93056
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - binary_accuracy: 0.9558 - loss: 0.2220 - mean_io_u_2: 0.3562 - val_binary_accuracy: 0.9178 - val_loss: 0.5266 - val_mean_io_u_2: 0.4217

# %%
if os.path.exists(checkpoint_path):
    model = tf.keras.models.load_model(
        checkpoint_path,
        custom_objects={"bce_dice_loss": bce_dice_loss, "dice_loss": dice_loss}
    )
    print("Loaded best model from", checkpoint_path)

test_eval = model.evaluate(test_ds, verbose=1)
print("Test evaluation (loss, binary_accuracy, meanIoU):", test_eval)
# Out:
# Loaded best model from resnet50.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 636ms/step - binary_accuracy: 0.9022 - loss: 0.7602 - mean_io_u_2: 0.4090
# Test evaluation (loss, binary_accuracy, meanIoU): [0.7511081099510193, 0.9105901122093201, 0.40074393153190613]

# %%
X_test_prep = preprocess_fn((X_test.astype(np.float32)) * 255.0)

y_pred = model.predict(X_test_prep, batch_size=batch_size)
y_pred_bin = (y_pred > 0.5).astype(np.uint8)

y_true_flat = Y_test.flatten().astype(np.uint8)
y_pred_flat = y_pred_bin.flatten().astype(np.uint8)

print("\nClassification Report:")
print(classification_report(y_true_flat, y_pred_flat, digits=4))

cm = confusion_matrix(y_true_flat, y_pred_flat)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["BG","FG"], yticklabels=["BG","FG"])
plt.title("Confusion Matrix")
plt.show()

def compute_iou(y_t, y_p):
    y_t = y_t.astype(bool)
    y_p = y_p.astype(bool)
    inter = np.logical_and(y_t, y_p).sum()
    union = np.logical_or(y_t, y_p).sum()
    if union == 0:
        return 1.0
    return inter / union

ious = []
for i in range(len(X_test)):
    iou = compute_iou(Y_test[i].squeeze(), y_pred_bin[i].squeeze())
    ious.append(iou)

print(f"Average IoU over test set: {np.mean(ious):.4f}")
print(f"Median IoU: {np.median(ious):.4f}")
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ab1eb282340> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ab1eb282340> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 849ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9724    0.9132    0.9418    597417
#            1     0.7307    0.9008    0.8069    156247
#
#     accuracy                         0.9106    753664
#    macro avg     0.8515    0.9070    0.8743    753664
# weighted avg     0.9223    0.9106    0.9138    753664
# Average IoU over test set: 0.7075
# Median IoU: 0.8569

# %%
def visualize_predictions(X_orig, Y_true, Y_pred_bin, indices=None, n=5, save_folder=None):
    if indices is None:
        sorted_idx = np.argsort(ious)
        picks = []
        picks.append(sorted_idx[0])
        picks.append(sorted_idx[-1])
        rng = np.random.default_rng(42)
        while len(picks) < n:
            p = int(rng.integers(0, len(X_orig)))
            if p not in picks:
                picks.append(p)
        indices = picks[:n]
    else:
        indices = indices[:n]

    plt.figure(figsize=(12, 4 * n))
    for i, idx in enumerate(indices):
        iou = compute_iou(Y_true[idx].squeeze(), Y_pred_bin[idx].squeeze())

        plt.subplot(n, 3, 3*i + 1)
        plt.imshow(X_orig[idx])
        plt.title(f"Image idx={idx}")
        plt.axis("off")

        plt.subplot(n, 3, 3*i + 2)
        plt.imshow(Y_true[idx].squeeze(), cmap="gray")
        plt.title("Ground Truth")
        plt.axis("off")

        plt.subplot(n, 3, 3*i + 3)
        plt.imshow(Y_pred_bin[idx].squeeze(), cmap="gray")
        plt.title(f"Prediction (IoU={iou:.3f})")
        plt.axis("off")

        if save_folder:
            os.makedirs(save_folder, exist_ok=True)
            plt.imsave(os.path.join(save_folder, f"pred_{idx}.png"), (Y_pred_bin[idx].squeeze()*255).astype(np.uint8), cmap="gray")

    plt.tight_layout()
    plt.show()

visualize_predictions(X_test, Y_test, y_pred_bin, n=6, save_folder=None)
